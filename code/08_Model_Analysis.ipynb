# %% [markdown]
# # Data Processing
#
# Change the data_path to your directory as needed
#
# 1.   key: the key pressed
# 2.   response_id: unique identifying code for this participant typing this
# target sentence
# 3. response_content: response for this sentence as typed in full
# 4. participant_id: unique ID for participant
# 5. sentence_id: identifier for target sentence
# 6. sentence_content: target sentence as displayed to the participant
# 7. diagnosis:
# > *   1=Typist has had a diagnosis of Parkinson's disease;
# > * 0=Typist has not had a diagnosis of Parkinson's disease
# 8. keydown: Timestamp for press of key in milliseconds
# 9. keyup: Timestamp for release of key in milliseconds

# %%
import pandas as pd
import numpy as np
import os
import re
import json

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#add path to data
data_path = '/content/drive/My Drive/266 Assignments/266 Final Project'

files = os.listdir(data_path)
files = [x for x in files if '.csv' in x]
files
# Out:
# ['online_english_fold_all.csv',
#  'MedicationInfo.csv',
#  'CoNLL_2020_Online_English.csv',
#  'cleaned_data.csv',
#  'depreciated_wrongAUC_calc_metrics.csv',
#  'analyzed_metrics.csv',
#  'cleaned_data_with_ft.csv',
#  'metrics.csv']

# %% [markdown]
# ## Get Model metrics

# %%
df = pd.read_csv(os.path.join(data_path, files[files.index('metrics.csv')]))
df
# Out:
#                                       model name            timestamp  \
# 0               CBOW-LSTM on characters & timing  2023-12-03 03:29:07
# 1               CBOW-LSTM on characters & timing  2023-12-03 03:30:27
# 2               CBOW-LSTM on characters & timing  2023-12-03 03:33:14
# 3                             BERT on characters  2023-12-03 03:47:51
# 4                             BERT on characters  2023-12-03 03:53:43
# 5                             BERT on characters  2023-12-03 03:59:42
# 6                             BERT on characters  2023-12-03 04:06:30
# 7                             BERT on characters  2023-12-03 04:14:25
# 8                             BERT on characters  2023-12-03 04:21:33
# 9                                  BERT on words  2023-12-03 04:32:01
# 10                                 BERT on words  2023-12-03 04:38:15
# 11                                 BERT on words  2023-12-03 04:44:23
# 12                       BERT-LSTM on characters  2023-12-03 04:58:43
# 13                       BERT-LSTM on characters  2023-12-03 05:04:34
# 14              BERT-LSTM on characters & timing  2023-12-03 05:08:13
# 15              BERT-LSTM on characters & timing  2023-12-03 05:19:37
# 16                            BERT-LSTM on words  2023-12-03 05:21:15
# 17                            BERT-LSTM on words  2023-12-03 05:27:07
# 18              BERT-LSTM on characters & timing  2023-12-03 05:32:24
# 19                            BERT-LSTM on words  2023-12-03 05:34:38
# 20       BERT-LSTM on characters, words & timing  2023-12-03 05:42:49
# 21                       BERT-LSTM on characters  2023-12-03 05:46:34
# 22       BERT-LSTM on characters, words & timing  2023-12-03 05:49:13
# 23       BERT-LSTM on characters, words & timing  2023-12-03 05:56:09
# 24                   BERT-LSTM on words & timing  2023-12-03 06:06:37
# 25                   BERT-LSTM on words & timing  2023-12-03 06:12:58
# 26                   BERT-LSTM on words & timing  2023-12-03 06:19:23
# 27         Chars2Vec-LSTM on characters & timing  2023-12-03 06:45:38
# 28         Chars2Vec-LSTM on characters & timing  2023-12-03 07:23:32
# 29         Chars2Vec-LSTM on characters & timing  2023-12-03 07:41:52
# 30         Chars2Vec-LSTM on characters & timing  2023-12-03 08:16:38
# 31         Chars2Vec-LSTM on characters & timing  2023-12-03 08:35:44
# 32         Chars2Vec-LSTM on characters & timing  2023-12-03 10:24:40
# 33                                      baseline  2023-12-03 19:44:23
# 34                                      baseline  2023-12-03 19:44:58
# 35                                      baseline  2023-12-03 19:45:07
# 36                                      baseline  2023-12-03 19:45:12
# 37                                      baseline  2023-12-03 19:45:45
# 38                                      baseline  2023-12-03 19:46:13
# 39                                      baseline  2023-12-03 19:46:46
# 40         CBOW-LSTM on characters & flight time  2023-12-05 22:13:47
# 41         CBOW-LSTM on characters & flight time  2023-12-05 22:16:45
# 42         CBOW-LSTM on characters & flight time  2023-12-05 22:17:57
# 43         CBOW-LSTM on characters & flight time  2023-12-05 22:19:02
# 44         CBOW-LSTM on characters & flight time  2023-12-05 22:20:52
# 45         CBOW-LSTM on characters & flight time  2023-12-05 22:23:05
# 46         CBOW-LSTM on characters & flight time  2023-12-05 22:25:32
# 47         CBOW-LSTM on characters & flight time  2023-12-05 22:27:49
# 48         BERT-LSTM on characters & flight time  2023-12-05 22:47:51
# 49         BERT-LSTM on characters & flight time  2023-12-06 00:34:55
# 50         BERT-LSTM on characters & flight time  2023-12-06 01:01:16
# 51         BERT-LSTM on characters & flight time  2023-12-06 01:27:51
# 52              BERT-LSTM on words & flight time  2023-12-06 01:58:00
# 53              BERT-LSTM on words & flight time  2023-12-06 02:23:08
# 54              BERT-LSTM on words & flight time  2023-12-06 03:03:07
# 55              BERT-LSTM on words & flight time  2023-12-06 03:28:41
# 56  BERT-LSTM on characters, words & flight time  2023-12-06 03:59:02
# 57  BERT-LSTM on characters, words & flight time  2023-12-06 04:24:25
# 58  BERT-LSTM on characters, words & flight time  2023-12-06 04:53:49
#
#     accuracy  precision    recall        f1       auc
# 0   0.525000   0.576471  0.417021  0.483951  0.490955
# 1   0.504545   0.532258  0.564103  0.547718  0.503029
# 2   0.495455   0.560748  0.255319  0.350877  0.536399
# 3   0.467120   0.000000  0.000000  0.000000       NaN
# 4   0.532880   0.532880  1.000000  0.695266       NaN
# 5   0.469388   0.555556  0.021277  0.040984       NaN
# 6   0.532880   0.532880  1.000000  0.695266  0.527866
# 7   0.532880   0.532880  1.000000  0.695266  0.495135
# 8   0.532880   0.532880  1.000000  0.695266  0.421865
# 9   0.532880   0.532880  1.000000  0.695266  0.462890
# 10  0.467120   0.000000  0.000000  0.000000  0.518002
# 11  0.467120   0.000000  0.000000  0.000000  0.526451
# 12  0.467120   0.000000  0.000000  0.000000  0.513706
# 13  0.467120   0.000000  0.000000  0.000000  0.510205
# 14  0.539683   0.574074  0.527660  0.549889  0.531295
# 15  0.528345   0.581818  0.408511  0.480000  0.575274
# 16  0.487528   0.520362  0.489362  0.504386  0.525945
# 17  0.462585   0.487500  0.165957  0.247619  0.484156
# 18  0.539683   0.572727  0.536170  0.553846  0.546716
# 19  0.510204   0.540084  0.544681  0.542373  0.527257
# 20  0.537415   0.637168  0.306383  0.413793  0.586924
# 21  0.532880   0.532880  1.000000  0.695266  0.519882
# 22  0.489796   0.522936  0.485106  0.503311  0.522619
# 23  0.505669   0.532567  0.591489  0.560484  0.491841
# 24  0.494331   0.523810  0.561702  0.542094  0.511113
# 25  0.494331   0.528037  0.480851  0.503341  0.486573
# 26  0.528345   0.562791  0.514894  0.537778  0.524024
# 27  0.503401   0.543011  0.429787  0.479810  0.547201
# 28  0.489796   0.553191  0.221277  0.316109  0.534910
# 29  0.537415   0.582888  0.463830  0.516588  0.550196
# 30  0.560091   0.645390  0.387234  0.484043  0.602004
# 31  0.514739   0.545852  0.531915  0.538793  0.532597
# 32  0.505669   0.536481  0.531915  0.534188  0.497067
# 33  0.453515   0.000000  0.000000  0.000000       NaN
# 34  0.453515   0.000000  0.000000  0.000000  0.500000
# 35  0.453515   0.000000  0.000000  0.000000  0.500000
# 36  0.453515   0.000000  0.000000  0.000000  0.500000
# 37  0.453515   0.000000  0.000000  0.000000  0.500000
# 38  0.467120   0.000000  0.000000  0.000000  0.500000
# 39  0.530612   0.000000  0.000000  0.000000  0.500000
# 40  0.702273   0.893939  0.502128  0.643052  0.832960
# 41  0.636364   0.885417  0.363248  0.515152  0.781131
# 42  0.545455   0.925000  0.158120  0.270073  0.807049
# 43  0.815909   0.877451  0.761702  0.815490  0.864140
# 44  0.668182   0.923077  0.410256  0.568047  0.842752
# 45  0.843182   0.936842  0.757447  0.837647  0.841598
# 46  0.829545   0.908163  0.757447  0.825986  0.853311
# 47  0.822727   0.910526  0.739316  0.816038  0.850545
# 48  0.634921   0.920455  0.344681  0.501548  0.833278
# 49  0.693878   0.938596  0.455319  0.613181  0.855113
# 50  0.718821   0.951220  0.497872  0.653631  0.842760
# 51  0.687075   0.929204  0.446809  0.603448  0.840054
# 52  0.671202   0.909091  0.425532  0.579710  0.847180
# 53  0.666667   0.885965  0.429787  0.578797  0.836253
# 54  0.684807   0.928571  0.442553  0.599424  0.833877
# 55  0.655329   0.902913  0.395745  0.550296  0.844371
# 56  0.696145   0.904000  0.480851  0.627778  0.845073
# 57  0.687075   0.929204  0.446809  0.603448  0.841789
# 58  0.730159   0.967742  0.510638  0.668524  0.848916

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

df = df.sort_values(by=['model name', 'timestamp'], ascending=[True, False])

df2 = df.groupby('model name').head(3)
df2
# Out:
#                                       model name           timestamp  \
# 8                             BERT on characters 2023-12-03 04:21:33
# 7                             BERT on characters 2023-12-03 04:14:25
# 6                             BERT on characters 2023-12-03 04:06:30
# 11                                 BERT on words 2023-12-03 04:44:23
# 10                                 BERT on words 2023-12-03 04:38:15
# 9                                  BERT on words 2023-12-03 04:32:01
# 21                       BERT-LSTM on characters 2023-12-03 05:46:34
# 13                       BERT-LSTM on characters 2023-12-03 05:04:34
# 12                       BERT-LSTM on characters 2023-12-03 04:58:43
# 51         BERT-LSTM on characters & flight time 2023-12-06 01:27:51
# 50         BERT-LSTM on characters & flight time 2023-12-06 01:01:16
# 49         BERT-LSTM on characters & flight time 2023-12-06 00:34:55
# 18              BERT-LSTM on characters & timing 2023-12-03 05:32:24
# 15              BERT-LSTM on characters & timing 2023-12-03 05:19:37
# 14              BERT-LSTM on characters & timing 2023-12-03 05:08:13
# 58  BERT-LSTM on characters, words & flight time 2023-12-06 04:53:49
# 57  BERT-LSTM on characters, words & flight time 2023-12-06 04:24:25
# 56  BERT-LSTM on characters, words & flight time 2023-12-06 03:59:02
# 23       BERT-LSTM on characters, words & timing 2023-12-03 05:56:09
# 22       BERT-LSTM on characters, words & timing 2023-12-03 05:49:13
# 20       BERT-LSTM on characters, words & timing 2023-12-03 05:42:49
# 19                            BERT-LSTM on words 2023-12-03 05:34:38
# 17                            BERT-LSTM on words 2023-12-03 05:27:07
# 16                            BERT-LSTM on words 2023-12-03 05:21:15
# 55              BERT-LSTM on words & flight time 2023-12-06 03:28:41
# 54              BERT-LSTM on words & flight time 2023-12-06 03:03:07
# 53              BERT-LSTM on words & flight time 2023-12-06 02:23:08
# 26                   BERT-LSTM on words & timing 2023-12-03 06:19:23
# 25                   BERT-LSTM on words & timing 2023-12-03 06:12:58
# 24                   BERT-LSTM on words & timing 2023-12-03 06:06:37
# 47         CBOW-LSTM on characters & flight time 2023-12-05 22:27:49
# 46         CBOW-LSTM on characters & flight time 2023-12-05 22:25:32
# 45         CBOW-LSTM on characters & flight time 2023-12-05 22:23:05
# 2               CBOW-LSTM on characters & timing 2023-12-03 03:33:14
# 1               CBOW-LSTM on characters & timing 2023-12-03 03:30:27
# 0               CBOW-LSTM on characters & timing 2023-12-03 03:29:07
# 32         Chars2Vec-LSTM on characters & timing 2023-12-03 10:24:40
# 31         Chars2Vec-LSTM on characters & timing 2023-12-03 08:35:44
# 30         Chars2Vec-LSTM on characters & timing 2023-12-03 08:16:38
# 39                                      baseline 2023-12-03 19:46:46
# 38                                      baseline 2023-12-03 19:46:13
# 37                                      baseline 2023-12-03 19:45:45
#
#     accuracy  precision    recall        f1       auc
# 8   0.532880   0.532880  1.000000  0.695266  0.421865
# 7   0.532880   0.532880  1.000000  0.695266  0.495135
# 6   0.532880   0.532880  1.000000  0.695266  0.527866
# 11  0.467120   0.000000  0.000000  0.000000  0.526451
# 10  0.467120   0.000000  0.000000  0.000000  0.518002
# 9   0.532880   0.532880  1.000000  0.695266  0.462890
# 21  0.532880   0.532880  1.000000  0.695266  0.519882
# 13  0.467120   0.000000  0.000000  0.000000  0.510205
# 12  0.467120   0.000000  0.000000  0.000000  0.513706
# 51  0.687075   0.929204  0.446809  0.603448  0.840054
# 50  0.718821   0.951220  0.497872  0.653631  0.842760
# 49  0.693878   0.938596  0.455319  0.613181  0.855113
# 18  0.539683   0.572727  0.536170  0.553846  0.546716
# 15  0.528345   0.581818  0.408511  0.480000  0.575274
# 14  0.539683   0.574074  0.527660  0.549889  0.531295
# 58  0.730159   0.967742  0.510638  0.668524  0.848916
# 57  0.687075   0.929204  0.446809  0.603448  0.841789
# 56  0.696145   0.904000  0.480851  0.627778  0.845073
# 23  0.505669   0.532567  0.591489  0.560484  0.491841
# 22  0.489796   0.522936  0.485106  0.503311  0.522619
# 20  0.537415   0.637168  0.306383  0.413793  0.586924
# 19  0.510204   0.540084  0.544681  0.542373  0.527257
# 17  0.462585   0.487500  0.165957  0.247619  0.484156
# 16  0.487528   0.520362  0.489362  0.504386  0.525945
# 55  0.655329   0.902913  0.395745  0.550296  0.844371
# 54  0.684807   0.928571  0.442553  0.599424  0.833877
# 53  0.666667   0.885965  0.429787  0.578797  0.836253
# 26  0.528345   0.562791  0.514894  0.537778  0.524024
# 25  0.494331   0.528037  0.480851  0.503341  0.486573
# 24  0.494331   0.523810  0.561702  0.542094  0.511113
# 47  0.822727   0.910526  0.739316  0.816038  0.850545
# 46  0.829545   0.908163  0.757447  0.825986  0.853311
# 45  0.843182   0.936842  0.757447  0.837647  0.841598
# 2   0.495455   0.560748  0.255319  0.350877  0.536399
# 1   0.504545   0.532258  0.564103  0.547718  0.503029
# 0   0.525000   0.576471  0.417021  0.483951  0.490955
# 32  0.505669   0.536481  0.531915  0.534188  0.497067
# 31  0.514739   0.545852  0.531915  0.538793  0.532597
# 30  0.560091   0.645390  0.387234  0.484043  0.602004
# 39  0.530612   0.000000  0.000000  0.000000  0.500000
# 38  0.467120   0.000000  0.000000  0.000000  0.500000
# 37  0.453515   0.000000  0.000000  0.000000  0.500000

# %%
# # Convert 'date_time_stamp' to datetime if it's not already in datetime format
# data['date_time_stamp'] = pd.to_datetime(data['date_time_stamp'])

# # Sort the DataFrame by 'model' and 'date_time_stamp' in descending order
# data = data.sort_values(by=['model', 'date_time_stamp'], ascending=[True, False])

# # Group by 'model' and select the top 3 rows for each group
# result = data.groupby('model').head(3)

# %%
# #drop first three rows of BERT on characters where auc was not exported and first three rows of Chars2Vec-LSTM.
# indices_to_exclude = [3, 4, 5, 27, 28, 29, 33, 34, 35, 36]

# df2 = df[~df.index.isin(indices_to_exclude)]
# df2

# %%
# new_data = {}

# df2.index = [
#     'baseline',
#     'BERT on characters',
#     'BERT-LSTM on characters',
#     'BERT-LSTM on characters & flight time',
#     'BERT on words',
#     'BERT-LSTM on words',
#     'BERT-LSTM on words & flight time',
#     'BERT-LSTM on characters, words & flight time',
#     'CBOW-LSTM on characters & flight time',
#     'Chars2Vec-LSTM on characters & flight time'
# ]

# for column in df2.columns:
#   mean_std = df[column].agg(['mean', 'std'])
#   new_data[column] = [f"{mean_std['mean']:.3f} ({mean_std['std']:.3f})"]

# new_df = pd.DataFrame(new_data)

# new_df

# %%
#get mean & stdev

agg_df = df2.groupby('model name').agg({'accuracy': ['mean', 'std'],
                                        'precision': ['mean', 'std'],
                                        'recall': ['mean', 'std'],
                                        'f1': ['mean', 'std'],
                                        'auc': ['mean', 'std']})

custom_order = ['baseline',
                'BERT on characters',
                'BERT-LSTM on characters',
                'BERT-LSTM on characters & flight time',
                'BERT on words',
                'BERT-LSTM on words',
                'BERT-LSTM on words & flight time',
                'BERT-LSTM on characters, words & flight time',
                'CBOW-LSTM on characters & flight time']
                # 'Chars2Vec-LSTM on characters & timing']

# len(agg_df['model name'])
# agg_df['model name'] = pd.Categorical(df['model name'], categories=custom_order, ordered=True)
agg_df = agg_df.reindex(custom_order)
agg_df.columns = ['_'.join(col) for col in agg_df.columns]
agg_df
# Out:
#                                               accuracy_mean  accuracy_std  \
# model name
# baseline                                           0.483749      0.041151
# BERT on characters                                 0.532880      0.000000
# BERT-LSTM on characters                            0.489040      0.037966
# BERT-LSTM on characters & flight time              0.699924      0.016715
# BERT on words                                      0.489040      0.037966
# BERT-LSTM on words                                 0.486772      0.023819
# BERT-LSTM on words & flight time                   0.668934      0.014869
# BERT-LSTM on characters, words & flight time       0.704460      0.022713
# CBOW-LSTM on characters & flight time              0.831818      0.010415
#
#                                               precision_mean  precision_std  \
# model name
# baseline                                            0.000000       0.000000
# BERT on characters                                  0.532880       0.000000
# BERT-LSTM on characters                             0.177627       0.307658
# BERT-LSTM on characters & flight time               0.939673       0.011047
# BERT on words                                       0.177627       0.307658
# BERT-LSTM on words                                  0.515982       0.026564
# BERT-LSTM on words & flight time                    0.905816       0.021451
# BERT-LSTM on characters, words & flight time        0.933648       0.032103
# CBOW-LSTM on characters & flight time               0.918511       0.015919
#
#                                               recall_mean  recall_std  \
# model name
# baseline                                         0.000000    0.000000
# BERT on characters                               1.000000    0.000000
# BERT-LSTM on characters                          0.333333    0.577350
# BERT-LSTM on characters & flight time            0.466667    0.027358
# BERT on words                                    0.333333    0.577350
# BERT-LSTM on words                               0.400000    0.204565
# BERT-LSTM on words & flight time                 0.422695    0.024197
# BERT-LSTM on characters, words & flight time     0.479433    0.031939
# CBOW-LSTM on characters & flight time            0.751403    0.010468
#
#                                                f1_mean    f1_std  auc_mean  \
# model name
# baseline                                      0.000000  0.000000  0.500000
# BERT on characters                            0.695266  0.000000  0.481622
# BERT-LSTM on characters                       0.231755  0.401412  0.514598
# BERT-LSTM on characters & flight time         0.623420  0.026612  0.845975
# BERT on words                                 0.231755  0.401412  0.502448
# BERT-LSTM on words                            0.431459  0.160339  0.512453
# BERT-LSTM on words & flight time              0.576172  0.024669  0.838167
# BERT-LSTM on characters, words & flight time  0.633250  0.032881  0.845259
# CBOW-LSTM on characters & flight time         0.826557  0.010816  0.848485
#
#                                                auc_std
# model name
# baseline                                      0.000000
# BERT on characters                            0.054277
# BERT-LSTM on characters                       0.004900
# BERT-LSTM on characters & flight time         0.008028
# BERT on words                                 0.034518
# BERT-LSTM on words                            0.024514
# BERT-LSTM on words & flight time              0.005503
# BERT-LSTM on characters, words & flight time  0.003567
# CBOW-LSTM on characters & flight time         0.006122

# %%
new_data = {}
for metric in ['accuracy', 'precision', 'recall', 'f1', 'auc']:
    mean_col = f'{metric}_mean'
    std_col = f'{metric}_std'
    new_data[metric] = agg_df[mean_col].apply(lambda x: f"{x:.3f}") + " (" + agg_df[std_col].apply(lambda x: f"{x:.3f}") + ")"

new_df = pd.DataFrame(new_data)

new_df
# Out:
#                                                    accuracy      precision  \
# model name
# baseline                                      0.484 (0.041)  0.000 (0.000)
# BERT on characters                            0.533 (0.000)  0.533 (0.000)
# BERT-LSTM on characters                       0.489 (0.038)  0.178 (0.308)
# BERT-LSTM on characters & flight time         0.700 (0.017)  0.940 (0.011)
# BERT on words                                 0.489 (0.038)  0.178 (0.308)
# BERT-LSTM on words                            0.487 (0.024)  0.516 (0.027)
# BERT-LSTM on words & flight time              0.669 (0.015)  0.906 (0.021)
# BERT-LSTM on characters, words & flight time  0.704 (0.023)  0.934 (0.032)
# CBOW-LSTM on characters & flight time         0.832 (0.010)  0.919 (0.016)
#
#                                                      recall             f1  \
# model name
# baseline                                      0.000 (0.000)  0.000 (0.000)
# BERT on characters                            1.000 (0.000)  0.695 (0.000)
# BERT-LSTM on characters                       0.333 (0.577)  0.232 (0.401)
# BERT-LSTM on characters & flight time         0.467 (0.027)  0.623 (0.027)
# BERT on words                                 0.333 (0.577)  0.232 (0.401)
# BERT-LSTM on words                            0.400 (0.205)  0.431 (0.160)
# BERT-LSTM on words & flight time              0.423 (0.024)  0.576 (0.025)
# BERT-LSTM on characters, words & flight time  0.479 (0.032)  0.633 (0.033)
# CBOW-LSTM on characters & flight time         0.751 (0.010)  0.827 (0.011)
#
#                                                         auc
# model name
# baseline                                      0.500 (0.000)
# BERT on characters                            0.482 (0.054)
# BERT-LSTM on characters                       0.515 (0.005)
# BERT-LSTM on characters & flight time         0.846 (0.008)
# BERT on words                                 0.502 (0.035)
# BERT-LSTM on words                            0.512 (0.025)
# BERT-LSTM on words & flight time              0.838 (0.006)
# BERT-LSTM on characters, words & flight time  0.845 (0.004)
# CBOW-LSTM on characters & flight time         0.848 (0.006)

# %%
new_df.to_csv(os.path.join(data_path, "analyzed_metrics_ft.csv"))
